// %%
let mut a = 1;

// %%
println!("{a}");
// Out:
// 1

// %%
{
    let b = &mut a;
    let c = &a;
    println!("{b}")
}
// Out:
// [unused_variables] Error: unused variable: `c`
//    ╭─[ command_14:1:1 ]
//    │
//  3 │     let c = &a;
//    │         ┬
//    │         ╰── warning: unused variable: `c`
//    │         │
//    │         ╰── help: if this is intentional, prefix it with an underscore: `_c`
// ───╯
// [E0502] Error: cannot borrow `a` as immutable because it is also borrowed as mutable
//    ╭─[ command_14:1:1 ]
//    │
//  2 │     let b = &mut a;
//    │             ───┬──
//    │                ╰──── mutable borrow occurs here
//  3 │     let c = &a;
//    │             ─┬
//    │              ╰── immutable borrow occurs here
//  4 │     println!("{b}")
//    │                ┬
//    │                ╰── mutable borrow later used here
// ───╯
